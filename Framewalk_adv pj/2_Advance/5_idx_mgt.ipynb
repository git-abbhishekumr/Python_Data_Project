# %% [markdown]
# # df.short_index( )
#
# ## Three methods  :
#
# ###  df.reset_index() , df.set_index() , df.short_index()

# %%
#Importing Libraries
import numpy as np
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading Data
datasets = load_dataset('lukebarousse/data_jobs')
df=datasets['train'].to_pandas()


#Data cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.sample(2)
# Out:
#       job_title_short              job_title   job_location     job_via  \
# 28913    Data Analyst           Data Analyst     Luxembourg  via Indeed
# 88387  Data Scientist  Visualization Analyst  Fort Mill, SC   via BeBee
#
#       job_schedule_type  job_work_from_home search_location  \
# 28913         Full-time               False      Luxembourg
# 88387         Full-time               False         Georgia
#
#           job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28913 2023-02-22 14:00:55                   True                 False
# 88387 2023-10-09 00:55:56                   True                 False
#
#          job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28913     Luxembourg        None              NaN              NaN
# 88387  United States        None              NaN              NaN
#
#          company_name                             job_skills  \
# 28913   Deutsche Bank  ['sql', 'oracle', 'tableau', 'excel']
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.index.name = "job_index"
df.head(2)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
#
#                            job_location           job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT   via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 0                          False                 False  United States
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # reset index

# %%
df_usa = df[df['job_country']=='United States']
df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
df_usa.reset_index(inplace=True)
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %% [markdown]
# # set Index

# %%
df_usa.set_index('job_index',inplace=True)
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %% [markdown]
# # short _index()

# %%
# Data Cleanup and Preparation
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])  # Convert date column to datetime

# Filtering for jobs in the United States
df_us = df[df['job_country'] == 'United States'].copy()

# Adding a column for the month the job was posted
df_us['job_posted_month'] = df_us['job_posted_date'].dt.strftime('%B')

# Creating a pivot table with job_posted_month as index and job_title_short as columns
df_us_pivot_table = df_us.pivot_table(index='job_posted_month', 
                                      columns='job_title_short', 
                                      aggfunc='size', 
                                      fill_value=0)

# Reset index to ensure the month_no column is integrated properly
df_us_pivot_table.reset_index(inplace=True)

# Displaying the resulting pivot table
print(df_us_pivot_table)
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_us_pivot_table is already defined and contains the data

# Convert 'job_posted_month' to a datetime object representing the month
df_us_pivot_table['month_no'] = pd.to_datetime(df_us_pivot_table['job_posted_month'], format='%B').dt.month

# Sort the DataFrame by the newly created 'month_no'
df_us_pivot_table.sort_values('month_no', inplace=True)

# Reset the index to use 'month_no' for plotting
df_us_pivot_table.set_index('month_no', inplace=True)

# Drop the unnecessary 'index' column if it exists
if 'index' in df_us_pivot_table.columns:
    df_us_pivot_table.drop(columns='index', inplace=True)

# Plotting
plt.figure(figsize=(10, 6))
df_us_pivot_table.drop(columns='job_posted_month').plot(kind='line', ax=plt.gca())

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Metric')  # Change this to what your y-axis represents
plt.title('Job Titles Over Time')

# Adjust the legend position to avoid overlapping
plt.legend(title='Job Titles', bbox_to_anchor=(1.05, 1), loc='upper left')

# Use tight layout to prevent overlap
plt.tight_layout()

# Show plot
plt.show()

# %%
# Get the top 3 job titles based on their frequency
top_3 = df_us['job_title_short'].value_counts().head(3)

# Convert the index (which contains the job titles) to a list
top_3_list = top_3.index.tolist()

# Print the list of top 3 job titles for verification
print(top_3_list)
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer']

# %%
df_us_pivot_table[top_3_list].plot(kind='line', ax=plt.gca())
# Out:
# <Axes: xlabel='month_no'>

# %%
pd.read_csv('https://lukeb.co/software_csv')
df_us_software_pivot= pd.read_csv('https://lukeb.co/software_csv',index_col= 'job_posted_month')
df_us_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_us_merged=(df_us_pivot_table.merge(df_us_software_pivot, on="job_posted_month"))

# %%
# Ensure you are working with only numeric data
numeric_df = df_us_merged.select_dtypes(include='number')

# Sum the values of each column, sort them in descending order, and get the top 5 column names
top_5 = numeric_df.sum().sort_values(ascending=False).head().index.to_list()

# Print the top 5 column names for verification
print(top_5)
# Out:
# ['Front-End Developer', 'Back-End Developer', 'Full-Stack Developer', 'Data Analyst', 'Data Scientist']

# %%
df_us_merged[top_5].plot(kind='line')
# Out:
# <Axes: >
