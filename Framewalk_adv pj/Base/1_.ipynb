# %%
import pandas as pd 
from datasets import load_dataset
import matplotlib.pylab as plt

datasets=load_dataset('lukebarousse/data_jobs')
df= datasets['train'].to_pandas()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df[["job_title_short","job_via"]]
# Out:
#              job_title_short                    job_via
# 0       Senior Data Engineer            via Work Nearby
# 1               Data Analyst           via BeBee México
# 2              Data Engineer               via LinkedIn
# 3              Data Engineer          via Diversity.com
# 4              Data Engineer         via Clearance Jobs
# ...                      ...                        ...
# 785736     Software Engineer        melalui Trabajo.org
# 785737          Data Analyst  melalui BeBee Deutschland
# 785738      Business Analyst           melalui Ricebowl
# 785739         Data Engineer        melalui Recruit.net
# 785740     Software Engineer             melalui Trigyn
#
# [785741 rows x 2 columns]

# %%
df.iloc[1]
# Out:
# job_title_short                                               Data Analyst
# job_title                                                     Data Analyst
# job_location                                  Guadalajara, Jalisco, Mexico
# job_via                                                   via BeBee México
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Mexico
# job_posted_date                                        2023-01-14 13:18:07
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Mexico
# salary_rate                                                           None
# ...

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.iloc[90:100,0:3]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location
# 90                   Australia
# 91               Temuco, Chile
# 92                    Anywhere
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.salary_year_avg.unique()
# Out:
# array([         nan, 109500.     , 140000.     , ..., 211511.     ,
#         66746.03125, 200935.5    ])

# %%
df[(df.job_title_short=="Data Analyst")&(df.salary_year_avg.notna())].head()
# Out:
#      job_title_short                                    job_title  \
# 109     Data Analyst        Senior Supply Chain Analytics Analyst
# 180     Data Analyst                             Data Analyst III
# 410     Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988     Data Analyst                        DATA ANALYST (ONSITE)
# 1413    Data Analyst                          Junior BI Developer
#
#             job_location                job_via job_schedule_type  \
# 109             Anywhere             via Get.It         Full-time
# 180        Dos Palos, CA  via My ArkLaMiss Jobs         Full-time
# 410   Atlantic Beach, FL   via ComputerJobs.com         Full-time
# 988      Springfield, MA             via Indeed         Full-time
# 1413         Atlanta, GA        via Ai-Jobs.net         Full-time
#
#       job_work_from_home            search_location      job_posted_date  \
# 109                 True    Illinois, United States  2023-10-12 13:02:19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.sort_values('job_posted_date',inplace=True)
df.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
df.dropna(subset =["salary_year_avg"])
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 334082          Data Engineer
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# ...                       ...
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
# 336301         Data Scientist
# 327439          Data Engineer
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 334082                                      Data Engineer         Argentina
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# ...                                                   ...               ...
# ...

# %%
df.drop(labels="salary_hour_avg",axis=1)
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860247552    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df.job_title_short.value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 785741

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(['min','max','median','count'])
# Out:
#                                min       max    median  count
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0    610
# Cloud Engineer             42000.0  280000.0   90000.0     65
# Data Analyst               25000.0  650000.0   90000.0   5451
# Data Engineer              15000.0  525000.0  125000.0   4500
# Data Scientist             27000.0  960000.0  127500.0   5922
# Machine Learning Engineer  30000.0  325000.0  106415.0    576
# Senior Data Analyst        30000.0  425000.0  111175.0   1131
# Senior Data Engineer       35000.0  425000.0  147500.0   1591
# Senior Data Scientist      45000.0  890000.0  155500.0   1690
# Software Engineer          28000.0  375000.0   99150.0    467

# %%
df['job_country'].value_counts(ascending=False)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Bhutan                 3
# Lesotho                3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
us_jobs = df[df['job_country']=="United States"]
us_jobs.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
us_jobs = us_jobs [us_jobs ['salary_year_avg'].notna()]
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_jobs_grouped = us_jobs.groupby('job_title_short')[['salary_year_avg']].agg(['median', 'min', 'max','count'])
sorted_us_jobs_grouped = us_jobs_grouped.sort_values(by=('salary_year_avg', 'median'), ascending=False)
print(sorted_us_jobs_grouped)
# Out:
#                           salary_year_avg
#                                    median      min       max count
# job_title_short
# Senior Data Scientist            155000.0  55000.0  475000.0  1241
# Machine Learning Engineer        150000.0  44408.5  315000.0   128
# Senior Data Engineer             150000.0  45000.0  375000.0  1058
# Data Scientist                   130000.0  30000.0  960000.0  4553
# Software Engineer                130000.0  48982.0  375000.0   157
# Data Engineer                    125000.0  23496.0  525000.0  2915
# Cloud Engineer                   116100.0  42000.0  221844.0    20
# Senior Data Analyst              110000.0  35360.0  425000.0   913
# Business Analyst                  90000.0  35000.0  387460.0   431
# Data Analyst                      90000.0  25000.0  375000.0  4350
